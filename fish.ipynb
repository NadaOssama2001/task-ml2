# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Fish.csv")
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
X=df.iloc[:,-1].values.reshape(-1,1)
y=df.iloc[:,1].values.reshape(-1,1)

# %%
X
# Out:
# array([[4.02  ],
#        [4.3056],
#        [4.6961],
#        [4.4555],
#        [5.134 ],
#        [4.9274],
#        [5.2785],
#        [4.69  ],
#        [4.8438],
#        [4.9594],
#        [5.1042],
#        [4.8146],
#        [4.368 ],
#        [5.0728],
#        [5.1708],
#        [5.58  ],
#        [5.2854],
#        [5.1975],
#        [5.1338],
#        [5.7276],
#        [5.5695],
#        [5.3704],
#        [5.2801],
#        [6.1306],
#        [5.589 ],
#        [6.0532],
#        [6.09  ],
#        [5.8515],
#        [6.1984],
#        [6.603 ],
#        [6.3063],
#        [6.292 ],
#        [6.7497],
#        [6.7473],
#        [6.3705],
#        [2.268 ],
#        [2.8217],
#        [2.9044],
#        [3.1746],
#        [3.5742],
#        [3.3516],
#        [3.3957],
#        [3.2943],
#        [3.7544],
#        [3.5478],
#        [3.8203],
#        [3.325 ],
#        [3.8   ],
#        [3.8352],
#        [3.6312],
#        [4.1272],
#        [3.906 ],
# ...

# %%
y
# Out:
# array([[ 242. ],
#        [ 290. ],
#        [ 340. ],
#        [ 363. ],
#        [ 430. ],
#        [ 450. ],
#        [ 500. ],
#        [ 390. ],
#        [ 450. ],
#        [ 500. ],
#        [ 475. ],
#        [ 500. ],
#        [ 500. ],
#        [ 340. ],
#        [ 600. ],
#        [ 600. ],
#        [ 700. ],
#        [ 700. ],
#        [ 610. ],
#        [ 650. ],
#        [ 575. ],
#        [ 685. ],
#        [ 620. ],
#        [ 680. ],
#        [ 700. ],
#        [ 725. ],
#        [ 720. ],
#        [ 714. ],
#        [ 850. ],
#        [1000. ],
#        [ 920. ],
#        [ 955. ],
#        [ 925. ],
#        [ 975. ],
#        [ 950. ],
#        [  40. ],
#        [  69. ],
#        [  78. ],
#        [  87. ],
#        [ 120. ],
#        [   0. ],
#        [ 110. ],
#        [ 120. ],
#        [ 150. ],
#        [ 145. ],
#        [ 160. ],
#        [ 140. ],
#        [ 160. ],
#        [ 169. ],
#        [ 161. ],
#        [ 200. ],
#        [ 180. ],
# ...

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_model= PolynomialFeatures(degree=5)
poly_model.fit_transform(X)
# Out:
# array([[1.00000000e+00, 4.02000000e+00, 1.61604000e+01, 6.49648080e+01,
#         2.61158528e+02, 1.04985728e+03],
#        [1.00000000e+00, 4.30560000e+00, 1.85381914e+01, 7.98180367e+01,
#         3.43664539e+02, 1.47968204e+03],
#        [1.00000000e+00, 4.69610000e+00, 2.20533552e+01, 1.03564761e+02,
#         4.86350476e+02, 2.28395047e+03],
#        [1.00000000e+00, 4.45550000e+00, 1.98514802e+01, 8.84482703e+01,
#         3.94081268e+02, 1.75582909e+03],
#        [1.00000000e+00, 5.13400000e+00, 2.63579560e+01, 1.35321746e+02,
#         6.94741844e+02, 3.56680463e+03],
#        [1.00000000e+00, 4.92740000e+00, 2.42792708e+01, 1.19633679e+02,
#         5.89482989e+02, 2.90461848e+03],
#        [1.00000000e+00, 5.27850000e+00, 2.78625623e+01, 1.47072535e+02,
#         7.76322375e+02, 4.09781766e+03],
#        [1.00000000e+00, 4.69000000e+00, 2.19961000e+01, 1.03161709e+02,
#         4.83828415e+02, 2.26915527e+03],
# ...

# %%
plt.scatter(X,y ,color='red')
plt.plot(X,model.predict(X),color='blue')
plt.title('fhish')
plt.xlabel('width')
plt.ylabel('weight')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_model= PolynomialFeatures(degree=5)
X_poly=poly_model.fit_transform(X)
line_poly=LinearRegression()
line_poly.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y ,color='red')
plt.plot(X,line_poly.predict(poly_model.fit_transform(X)),color='blue')
plt.title('fish')
plt.xlabel('width')
plt.ylabel('weight')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_model= PolynomialFeatures(degree=15)
X_poly=poly_model.fit_transform(X)
line_poly=LinearRegression()
line_poly.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y ,color='red')
plt.plot(X,line_poly.predict(poly_model.fit_transform(X)),color='blue')
plt.title('fish')
plt.xlabel('width')
plt.ylabel('weight')
plt.show()
